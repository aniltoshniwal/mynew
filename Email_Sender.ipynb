# %%
import smtplib
s=smtplib.SMTP('smtp.gmail.com',587)
s.ehlo()
s.starttls()
s.ehlo()
email=input('Enter Email ID: ')
pwd=input('Enter Password: ')
s.login(email,pwd)
msg=input("Write your msg: ")
reciver_Email=input('Enter Reciever Email ID: ')
s.sendmail(email,reciver_Email,msg)
s.quit()

# %%
import smtplib
import email
msg = email.message.Message()
msg["From"] = "usersafe3@gmail.com"
msg["To"] = "dharmndra076@gmail.com"
msg["Subject"] = "Test message"
server = smtplib.SMTP("smtp.gmail.com",587)
server.starttls()
server.ehlo_or_helo_if_needed()
try:
    failed = server.sendmail("usersafe3@gmail.com","dharmndra076@gmail.com", msg.as_string())
    server.close()
except Exception as e:
    print(e)
# Out:
# (530, b'5.5.1 Authentication Required. Learn more at\n5.5.1  https://support.google.com/mail/?p=WantAuthError f33sm2265464pgl.33 - gsmtp', 'usersafe3@gmail.com')

# %%
import sys
import chilkat2
from email.mime.text import MIMEText
from email.mime.text import MIMEText
import email.Utils
import smtplib

FROM = "usersafe3@gmail.com"
TO = "dharmndra076@gmail.com"
message = "This Email is send by Python\n Python is Great !!!"
msg = MIMEText(message)
msg["Subject"] = "Email Notification by Python"
msg["Message-id"] = email.Utils.make_msgid()
msg["From"] = FROM
msg["To"] = TO
host = "smtp.gmail.com"
server = smtplib.SMTP(host)
server.sendmail(FROM, TO, msg.as_string())
server.quit()
print ('Email Send')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-12c441cb66a4> in <module>
#       3 from email.mime.text import MIMEText
#       4 from email.mime.text import MIMEText
# ----> 5 import email.Utils
#       6 import smtplib
#       7
#
# ModuleNotFoundError: No module named 'email.Utils'

# %%
pip install --user email
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/71/e7/816030d3b0426c130040bd068be62b9213357ed02896f5d9badcf46d1b5f/email-4.0.2.tar.gz
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ikv306to/email/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ikv306to/email/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-install-ikv306to/email/pip-egg-info
#          cwd: /tmp/pip-install-ikv306to/email/
#     Complete output (39 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/usr/lib/python3/dist-packages/setuptools/__init__.py", line 12, in <module>
#         import setuptools.version
# ...

# %%
os.listdir('/home/am/.local/lib/python3.6/site-packages')
# Out:
# ['astor-0.8.0.dist-info',
#  'qtconsole',
#  'pyrsistent',
#  'dash_html_components-1.0.1.dist-info',
#  'jedi',
#  'bleach-3.1.0.dist-info',
#  'keras_preprocessing',
#  'lxml',
#  'geocoder-1.38.1.dist-info',
#  'SpeechRecognition-3.8.1.dist-info',
#  'Pygments-2.4.2.dist-info',
#  'jsonschema-3.1.1.dist-info',
#  'entrypoints-0.3.dist-info',
#  'jinja2',
#  'Crypto',
#  'olefile',
#  'tensorflow_core',
#  'sortedcontainers',
#  '_pyrsistent_version.py',
#  'pygments',
#  'beautifulsoup4-4.8.0.dist-info',
#  'zmq',
#  'terminado-0.8.2.dist-info',
#  'keras_applications',
#  'ipykernel',
#  'absl_py-0.8.1.dist-info',
#  'grpcio-1.24.1.dist-info',
#  'distro-1.4.0.dist-info',
#  'xlsxwriter',
#  'tensorflow_estimator-2.0.0.dist-info',
#  'speech_recognition',
#  'PyPDF2',
#  'pymongo',
#  'dash_html_components',
#  'IPython',
#  'parso-0.5.1.dist-info',
#  'pptx',
#  'jdcal-1.4.1.dist-info',
#  'attr',
#  'ipykernel-5.1.2.dist-info',
#  'ipython_genutils-0.2.0.dist-info',
# ...
