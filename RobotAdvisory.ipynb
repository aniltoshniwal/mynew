# %% [raw]
# details={}
# print(r'''1. How old are you? (Promise we won't tell)''')
# print('''a. Under 30''')
# print('''b. 30s''')
# print('''c. 40s''')
# print('''d. 50s''')
# print('''e. 60s''')
# a = input('Please Choose one: ').lower()
# if a=='a':
#     age=[18,30]
#     details['age']=age
# elif a=='b':
#     age=[30,40]
#     details['age']=age
# elif a=='c':
#     age=[40,50]
#     details['age']=age
# elif a=='d':
#     age=[50,60]
#     details['age']=age
# elif a=='e':
#     age=[60,100]
#     details['age']=age
#
#
# print(r'''2. What is your status?''')
# print("a. Single")
# print("b. Married")
# print("c. Divorced")
# b = input('Please Choose one: ').lower()
# if b=='a':
#     status='Single'
#     details['status']=status
# elif b=='b':
#     status='Married'
#     details['status']=status
# elif b=='c':
#     status='Divorced'
#     details['status']=status
#
# print(r'''3. Bringing home the bacon - what's your annual household income?''')
# print("a. Under $75,000")
# print("b. $75,000 to $125,000")
# print("c. $125,000 to $200,000")
# print("d. $200,000 to $400,000")
# print("e. Over $400,000")
# c = input('Please Choose one: ').lower()
# if c=='a':
#     anual_in=[75000]
#     details['anual_income']=anual_in
# elif c=='b':
#     anual_in=[75000,125000]
#     details['anual_income']=anual_in
# elif c=='c':
#     anual_in=[125000,200000]
#     details['anual_income']=anual_in
# elif c=='d':
#     anual_in=[200000,400000]
#     details['anual_income']=anual_in
# elif c=='e':
#     anual_in=[400000]
#     details['anual_income']=anual_in
#
# print(r'''4. How much do you have in total savings? i.e. retirement, investments & cash accounts.''')
# print("a. Under $100,000")
# print("b. $100,000 to $400,000")
# print("c. $400,000 to $800,000")
# print("e. $800,000 to $1,500,000")
# print("f. $1,500,000 to $4,000,000")
# print("g. Over $4,000,000")
# d = input('h. Please Choose one: ').lower()
# if d=='a':
#     anual_sa=[75000]
#     details['anual_saving']=anual_sa
# elif d=='b':
#     anual_sa=[75000,125000]
#     details['anual_saving']=anual_sa
# elif d=='c':
#     anual_sa=[125000,200000]
#     details['anual_saving']=anual_sa
# elif d=='d':
#     anual_sa=[200000,400000]
#     details['anual_saving']=anual_sa
# elif d=='e':
#     anual_sa=[400000]
#     details['anual_saving']=anual_sa
#
# print(r'''5. Do you have liabilities?''')
# print(r"Yes\NO")
# p=input('Please Choose one: ').lower()
# if p=='yes':
#     liabilities=True
#     details['liabilities']=liabilities
# elif p=='no':
#     liabilities=False
#     details['liabilities']=liabilities
#
# print(r'''5. Do you own a business?''')
# print(r"Yes\No")
# e = input('Please Choose one: ').lower()
# if e=='yes':
#     business=True
#     details['business']=business
# elif e=='no':
#     business=False
#     details['business']=business
#
# print(r'''6. Are you currently working with a financial advisor?''')
# print(r"No\Yes")
# f = input('Please Choose one: ').lower()
# if f=='yes':
#     advisor=True
#     details['advisor']=advisor
# elif f=='no':
#     advisor=False
#     details['advisor']=advisor
#
# print(r'''7. What type of service are you looking for?''')
# print('a. Financial Planning')
# print('b. Investment Management')
# print('c. Both')
# print('d. Unsure')
# print('e. Something Else')
# g = input('Please Choose one: ').lower()
# if g=='a':
#     looking_for = 'Financial Planning'
#     details['looking_for'] = looking_for
# elif g=='b':
#     looking_for = 'Investment Management'
#     details['looking_for'] = looking_for
# elif g=='c':
#     looking_for = 'Both'
#     details['looking_for'] = looking_for
# elif g=='d':
#     looking_for = 'Unsure'
#     details['looking_for'] = looking_for
# elif g=='e':
#     looking_for = 'Something Else'
#     details['looking_for'] = looking_for
#
# print(r'''8. What type of relationship are you looking for?''')
# print('a. One Time Plan')
# print('b. Ongoing Advice')
# print('c. Unsure')
# h = input('Please Choose one: ').lower()
# if h=='a':
#     ralationship='One Time Plan'
#     details['ralationship'] = ralationship
# elif h=='b':
#     ralationship='Ongoing Advice'
#     details['ralationship'] = ralationship
# elif h=='c':
#     ralationship='Unsure'
#     details['ralationship'] = ralationship
#
#
# print(r'''9. How important is having your financial advisor from?''')
# #print('a. Not important')
# #print('b. Nice to have')
# #print('c. Very important')
# i = input('Please Enter Your State: ').lower()
# details['State'] = i
# ii = input('Please Enter Your city: ').lower()
# details['city'] = ii
#
#
# print(r'''10. Which of the following best describes your goals? (Max 3)''')
# print('a. Prepare for retirement')
# print("b. Save for kid's college")
# print('c. Access to alternative investments')
# print('d. Diversify concentrated wealth')
# print('e. Manage my inheritance')
# print('f. Optimize my taxes')
# print('g. Pay down debt')
# print('h. Start my own business')
# print('i. Manage new wealth')
# print('j. Socially responsible investingm')
# print('k. Philanthropy')
# print('l. Improve budgeting')
# j, k, l = input("Please Choose any Three(separated by ',' ): ").lower().split(',')
# goal=[]
# if j=='a':
#     goals='Prepare for retirement'
#     goal.append(goals)
# elif j=='b':
#     goals="Save for kid's college"
#     goal.append(goals)
# elif j=='c':
#     goals='Access to alternative investments'
#     goal.append(goals)
# elif j=='d':
#     goals='Diversify concentrated wealth'
#     goal.append(goals)
# elif j=='e':
#     goals='Manage my inheritance'
#     goal.append(goals)
# elif j=='f':
#     goals='Optimize my taxes'
#     goal.append(goals)
# elif j=='g':
#     goals='Pay down debt'
#     goal.append(goals)
# elif j=='h':
#     goals='Start my own business'
#     goal.append(goals)
# elif j=='i':
#     goals='Manage new wealth'
#     goal.append(goals)
# elif j=='j':
#     goals='Socially responsible investingm'
#     goal.append(goals)
# elif j=='k':
#     goals='Philanthropy'
#     goal.append(goals)
# elif j=='l':
#     goals='Improve budgeting'
#     goal.append(goals)
# if k=='a':
#     goals='Prepare for retirement'
#     goal.append(goals)
# elif k=='b':
#     goals="Save for kid's college"
#     goal.append(goals)
# elif k=='c':
#     goals='Access to alternative investments'
#     goal.append(goals)
# elif k=='d':
#     goals='Diversify concentrated wealth'
#     goal.append(goals)
# elif k=='e':
#     goals='Manage my inheritance'
#     goal.append(goals)
# elif k=='f':
#     goals='Optimize my taxes'
#     goal.append(goals)
# elif k=='g':
#     goals='Pay down debt'
#     goal.append(goals)
# elif k=='h':
#     goals='Start my own business'
#     goal.append(goals)
# elif k=='i':
#     goals='Manage new wealth'
#     goal.append(goals)
# elif k=='j':
#     goals='Socially responsible investingm'
#     goal.append(goals)
# elif k=='k':
#     goals='Philanthropy'
#     goal.append(goals)
# elif k=='l':
#     goals='Improve budgeting'
#     goal.append(goals)
# if l=='a':
#     goals='Prepare for retirement'
#     goal.append(goals)
# elif l=='b':
#     goals="Save for kid's college"
#     goal.append(goals)
# elif l=='c':
#     goals='Access to alternative investments'
#     goal.append(goals)
# elif l=='d':
#     goals='Diversify concentrated wealth'
#     goal.append(goals)
# elif l=='e':
#     goals='Manage my inheritance'
#     goal.append(goals)
# elif l=='f':
#     goals='Optimize my taxes'
#     goal.append(goals)
# elif l=='g':
#     goals='Pay down debt'
#     goal.append(goals)
# elif l=='h':
#     goals='Start my own business'
#     goal.append(goals)
# elif l=='i':
#     goals='Manage new wealth'
#     goal.append(goals)
# elif l=='j':
#     goals='Socially responsible investingm'
#     goal.append(goals)
# elif l=='k':
#     goals='Philanthropy'
#     goal.append(goals)
# elif l=='l':
#     goals='Improve budgeting'
#     goal.append(goals)
# details['goals']=goal
# details

# %%
advisor = {
    "item": {
        "advisors": [

            {
                "id": 1,
                "Name": "Mukesh Bhardwaj",
                "Gender": "Male",
                "city": "Noida",
                "Experience": "7",
                "state": "Uttar Pradesh",
                "pin": '201301',
                "specialization": ["ETFS"],
                "advise_fee":'2000',
                "education":['Bachelor of Commerce (Finance) 2010','Diploma of Financial Services (Financial Planning) (2005)'],
                "categories":['Retirement planing','Estate Planing','Education Planing','Business Planing','Insurance Planing',
                            'Investment Planing'],
                'rating':'4',
                'relationship':['One time', 'Ongoing advise'],
                'fee_type':['Fixed','Variable'],
                'AUM':'10000000000'

            },
            {
                "id": 2,
                "Name": "Aniska Sexsena",
                "Gender": "Female",
                "city": "Noida",
                "Experience": "8",
                "state": "Uttar Pradesh",
                "pin": '24400901',
                "specialization": ["Bonds"],
                "advise_fee":'3000',
                "education":['Bachelor of Commerce (Finance) 2010','Diploma of Financial Services (Financial Planning) (2005)'],
                "categories":['Retirement planing'],
                'rating':'4',
                'relationship':['Ongoing advise'],
                'fee_type':['Variable'],
                'AUM':'10000000000'

            },
            {
                "id": 3,
                "Name": "Dharmendra Singh",
                "Gender": "Male",
                "city": "Noida",
                "Experience": "5",
                "state": "Uttar Pradesh",
                "pin": '244924',
                "specialization": ["Mutual Fund", "Equity"],
                "advise_fee":'2000',
                "education":['Bachelor of Commerce (Finance) 2010','Diploma of Financial Services (Financial Planning) (2005)'],
                "categories":['Education Planing','Business Planing','Insurance Planing',
                            'Investment Planing'],
                'rating':'4',
                'relationship':['One time'],
                'fee_type':['Variable'],
                'AUM':'10000000000'


            },
            {
                "id": 4,
                "Name": "Rahul Singh",
                "Gender": "Male",
                "city": "Noida",
                "Experience": "5",
                "state": "Uttar Pradesh",
                "pin": '244001',
                "specialization": ["Equity", "ETFS"],
                "advise_fee":'2000',
                "education":['Bachelor of Commerce (Finance) 2010','Diploma of Financial Services (Financial Planning) (2005)'],
                "categories":['Estate Planing'],
                'rating':'4',
                'relationship':['Ongoing advise'],
                'fee_type':['Fixed'],
                'AUM':'10000000000'

            },

        ]
    }
}

# %%
import json
with open('Advisors.json', 'w') as file:
    json.dump(advisor, file)
data=json.loads(open('Advisors.json').read())
advisor_data=data['item']['advisors']

# %%
detail={'age': [30, 40],
 'status': 'Single',
 'anual_income': [1000000,2500000 ],
 'anual_saving': [200000, 500000],
 'liabilities':200000,
 'business': False,
 'advisor': False,
 'looking_for':['Retirement planing','Estate Planing'],
 'relationship':['Unsure'],
 'fee_type':['Fixed'],
 'State': 'Uttar Pradesh',
 'city': 'Noida',
 'pin':'201301',
 'specialization': ['ETFS','Bonds']}

# %%
print(detail['fee_type'])
print(detail['relationship'])
print(detail['looking_for'])
print(detail['specialization'])
print(detail['State'])
print(detail['city'])
print(detail['pin'])
# Out:
# ['Fixed']
# ['Unsure']
# ['Retirement planing', 'Estate Planing']
# ['ETFS', 'Bonds']
# Uttar Pradesh
# Noida
# 201301

# %% [markdown]
# # 1. Find Advisor based on categories, State, City and specialization

# %%
d=[]
for i in range(len(advisor_data)):
    for j in range(len(detail['looking_for'])):
        if detail['looking_for'][j] in advisor_data[i]['categories'] and detail['State']==advisor_data[i]['state'] and detail['city']== advisor_data[i]['city']:
            if advisor_data[i] not in d:
                d.append(advisor_data[i])
find_data=[]                
for i in range(len(advisor_data)):
    for k in range(len(detail['specialization'])):
        if detail['specialization'][k] in advisor_data[i]['specialization']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])
find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 2,
#   'Name': 'Aniska Sexsena',
#   'Gender': 'Female',
#   'city': 'Noida',
#   'Experience': '8',
#   'state': 'Uttar Pradesh',
#   'pin': '24400901',
#   'specialization': ['Bonds'],
#   'advise_fee': '3000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...

# %% [markdown]
# # 2. Find Advisor based on categories

# %%
find_data=[]
for i in range(len(advisor_data)):
    for j in range(len(detail['looking_for'])):
        if detail['looking_for'][j] in advisor_data[i]['categories']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])

find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 2,
#   'Name': 'Aniska Sexsena',
#   'Gender': 'Female',
#   'city': 'Noida',
#   'Experience': '8',
#   'state': 'Uttar Pradesh',
#   'pin': '24400901',
#   'specialization': ['Bonds'],
#   'advise_fee': '3000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...

# %% [markdown]
# # 3. Find Advisor based on specialization

# %%
find_data=[]                
for i in range(len(advisor_data)):
    for k in range(len(detail['specialization'])):
        if detail['specialization'][k] in advisor_data[i]['specialization']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])
find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 2,
#   'Name': 'Aniska Sexsena',
#   'Gender': 'Female',
#   'city': 'Noida',
#   'Experience': '8',
#   'state': 'Uttar Pradesh',
#   'pin': '24400901',
#   'specialization': ['Bonds'],
#   'advise_fee': '3000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...

# %% [markdown]
# # 4. Find Advisor based on Location

# %%
find_data=[]
for i in range(len(advisor_data)):
    for j in range(len(detail['State'])):
        if detail['State']==advisor_data[i]['state'] and detail['city']== advisor_data[i]['city']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])

find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 2,
#   'Name': 'Aniska Sexsena',
#   'Gender': 'Female',
#   'city': 'Noida',
#   'Experience': '8',
#   'state': 'Uttar Pradesh',
#   'pin': '24400901',
#   'specialization': ['Bonds'],
#   'advise_fee': '3000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...

# %% [markdown]
# # 5. Find Advisor based on Fee Type

# %%
find_data=[]
for i in range(len(advisor_data)):
    for j in range(len(detail['fee_type'])):
        if detail['fee_type'][j] in advisor_data[i]['fee_type']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])

find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 4,
#   'Name': 'Rahul Singh',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '5',
#   'state': 'Uttar Pradesh',
#   'pin': '244001',
#   'specialization': ['Equity', 'ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...

# %% [markdown]
# # 6. Find Advisor based on Relationship

# %%
find_data=[]
for i in range(len(advisor_data)):
    for j in range(len(detail['relationship'])):
        if detail['relationship'][j]=='Unsure':
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])
        elif detail['relationship'][j] in advisor_data[i]['relationship']:
            if advisor_data[i] not in find_data:
                find_data.append(advisor_data[i])
            

find_data
# Out:
# [{'id': 1,
#   'Name': 'Mukesh Bhardwaj',
#   'Gender': 'Male',
#   'city': 'Noida',
#   'Experience': '7',
#   'state': 'Uttar Pradesh',
#   'pin': '201301',
#   'specialization': ['ETFS'],
#   'advise_fee': '2000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
#   'categories': ['Retirement planing',
#    'Estate Planing',
#    'Education Planing',
#    'Business Planing',
#    'Insurance Planing',
#    'Investment Planing'],
#   'rating': '4',
#   'relationship': ['One time', 'Ongoing advise'],
#   'fee_type': ['Fixed', 'Variable'],
#   'AUM': '10000000000'},
#  {'id': 2,
#   'Name': 'Aniska Sexsena',
#   'Gender': 'Female',
#   'city': 'Noida',
#   'Experience': '8',
#   'state': 'Uttar Pradesh',
#   'pin': '24400901',
#   'specialization': ['Bonds'],
#   'advise_fee': '3000',
#   'education': ['Bachelor of Commerce (Finance) 2010',
#    'Diploma of Financial Services (Financial Planning) (2005)'],
# ...
