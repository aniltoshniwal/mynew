# %%
import geocoder

# %% [raw]
# g = geocoder.ip('14.143.74.69')
# g = geocoder.ip('me')
# print(g.latlng)

# %% [raw]
# g.city

# %% [raw]
# g.street

# %% [raw]
# g.postal

# %% [raw]
# import pandas as pd
# import numpy as np
# data={'Noida':np.array(['Mr. A','Mr. B','Mr. C','Mr. D','Mr. E']),
#       'Moradabad':np.array(['Mr. F','Mr. G','Mr. H','Mr. I','Mr. J']),
#       'Rampur':np.array(['Mr. K','Mr. L','Mr. M','Mr. N','Mr. O']),
#     'Specialization':np.array(['Equities','Bonds','Mutual Fund','ETFS','Future & Options']),
#     'State':np.array(['Uttar Pradesh','Delhi','Haryana','Rajasthan','Bihar']),
#      'Uttar Pradesh':np.array(['Noida','Moradabadloa','Rampur']),
#       'Delhi':np.array(['Delhi NCR']),
#       'Haryana':np.array(['Harrayana']),
#       'Rajasthan':np.array('Rajasthan')}
#
# data1=[['Mr. A','Mr. B','Mr. C','Mr. D','Mr. E'],['Mr. F','Mr. G','Mr. H','Mr. I','Mr. J'],
# ['Mr. K','Mr. L','Mr. M','Mr. N','Mr. O'],['Equities','Bonds','Mutual Fund','ETFS','Future & Options'],
# ['Uttar Pradesh','Delhi','Haryana','Rajasthan'],['Noida','Moradabad','Rampur'],'Delhi NCR','Haryana',
# 'Rajasthan']
# col=['Noida','Moradabad','Rampur','Specialization','State','Uttar Pradesh','Delhi','Haryana','Rajasthan']

# %% [raw]
# df=pd.DataFrame(data)

# %% [raw]
# #len(data1)
# #df.to_csv('data.csv')
# df.head()

# %% [raw]
# for i in range(len(df['State'])):
#     print(f"{i+1}.{df['State'][i]}")
# s=int(input('Select State: '))
#
# for i in range(len(df[df['State'][s-1]])):
#   print(f"{i+1}.{df[df['State'][s-1]][i]}")
# k=int(input('Select City: '))
# print(f"Selected city {df[df['State'][s-1]][k-1]}")
# for i in range(len(df['Specialization'])):
#       print(f"{i+1}.{df['Specialization'][i]}")
# p=int(input('Select Specialization: '))
# #for i in range(len(df[df['State'][s-1]][k-1])):
# print(df[df[df['State'][s-1]][k-1]][p-1])

# %%
s=1
for i in range(len(df[df['State'][s-1]])):
              print(f"{i+1}.{df[df['State'][s-1]][i]}")

# %%
df[df['State'][s-1]]

# %%
len(df['State'])

# %%
df=pd.read_csv('data.csv',index=0)

# %%
import sys
import json
from difflib import get_close_matches
st=[]
ct=[]
class search_advisor():
    def __init__(self):
        data = json.loads(open('/home/am/python/Indian-States-And-Districts/states-and-districts.json').read())
        state = input('Select state name: ').title()
        f = [data['states'][i]['state'] for i in range(len(data['states']))]
        self.data=data
        self.state=state
        self.f=f
    def state_one(self):
        global st
        if self.state in self.f:
            st = self.state
            print(f'Selected State {st}')
            return self.data, self.f
        find_state = [i for i in get_close_matches(self.state, self.f)]
        if len(find_state) == 1:

            for i in find_state:
                st = i
                print(f'Selected State {st}')
                return self.data, self.f


        elif len(find_state) >= 2:
            j = 1
            state_more = []
            for i in find_state:
                print(f'{j}.{i}')
                state_more.append(i)
                j += 1
            in_again = int(input('Choose any one: '))
            if state_more[in_again - 1] in state_more:

                st = state_more[in_again - 1]
                print(f'Selected State {st}')
                return st, self.data, self.f
            else:
                print('enter correct')

        else:
            print('State not found!')
        raise SystemExit()
    def city_one(self):
        global st
        print(st)
        #st, data, f = state_one()
        # print(st)
        city = input('Select City name: ').title()
        # for s in range(len(data['states'])):
        find_city = [i for i in get_close_matches(city, self.data['states'][self.f.index(st)]['districts'])]
        if city in data['states'][self.f.index(st)]['districts']:
            ct = city
            print(f'Selected City {ct}')
            return ct
        elif len(find_city) == 1:
            for i in find_city:
                ct = i
                print(f'Selected City {ct}')
                return ct
        elif len(find_city) >= 2:

            for i in find_city:
                j = 1
            city_more = []
            for i in find_city:
                print(f'{j}.{i}')
                city_more.append(i)
                j += 1
            in_again = int(input('Choose any one: '))
            if city_more[in_again - 1] in city_more:
                ct = city_more[in_again - 1]
                print(f'Selected City {ct}')
                return ct,st
            else:
                print('enter correct')
            # return st
        else:
            print('State not found!')
            raise SystemExit()

# %%
a=search_advisor()
a.city_one()

# %%
    def city_one():
        st, data, f = state_one()
        # print(st)
        city = input('Select City name: ').title()
        # for s in range(len(data['states'])):
        find_city = [i for i in get_close_matches(city, data['states'][f.index(st)]['districts'])]
        if city in data['states'][f.index(st)]['districts']:
            ct = city
            print(f'Selected City {ct}')
            return ct
        elif len(find_city) == 1:
            for i in find_city:
                ct = i
                print(f'Selected City {ct}')
                return ct
        elif len(find_city) >= 2:

            for i in find_city:
                j = 1
            city_more = []
            for i in find_city:
                print(f'{j}.{i}')
                city_more.append(i)
                j += 1
            in_again = int(input('Choose any one: '))
            if city_more[in_again - 1] in city_more:
                ct = city_more[in_again - 1]
                print(f'Selected City {ct}')
                return ct,st
            else:
                print('enter correct')
            # return st
        else:
            print('State not found!')
            raise SystemExit()

# %%
a=''
b='New Delhi'
print(a+b)

# %%
list={'Delhi (NCT)':[]}

# %%
import sys
import json
from difflib import get_close_matches
data = json.loads(open('/home/am/python/Indian-States-And-Districts/states-and-districts.json').read())

# %%
a={"states":[{
    "state":"Delhi (NCT)",
         "districts":[{  
            "Central Delhi":['Equities', 'Bonds', 'Mutual Fund', 'ETFS', 'Future & Options']},
            "East Delhi",
            "New Delhi",
            "North Delhi",
            "North East  Delhi",
            "North West  Delhi",
            "Shahdara",
            "South Delhi",
            "South East Delhi",
            "South West  Delhi",
            "West Delhi"
         ]}]
      },

# %%
type(a)

# %%
pdfFilePath = '/home/am/Downloads/read.pdf'
fileObject = open(pdfFilePath, 'rb')
pdfFileReader = PyPDF2.PdfFileReader(fileObject)
pdf=pdfFileReader.getPage(0) 
#print(pdf.extractText())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e6d6160daacc> in <module>
#       1 pdfFilePath = '/home/am/Downloads/read.pdf'
#       2 fileObject = open(pdfFilePath, 'rb')
# ----> 3 pdfFileReader = PyPDF2.PdfFileReader(fileObject)
#       4 pdf=pdfFileReader.getPage(0)
#       5 #print(pdf.extractText())
#
# NameError: name 'PyPDF2' is not defined

# %%
from tabula import read_pdf
df=read_pdf('/home/am/Downloads/read.pdf')
import pandas as pd
df1=pd.DataFrame(df)
df1

# %%
# Out:
#                                                Name :  \
# 0                                                 NaN
# 1                                           Address :
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                             Phone :
# 9                                                 NaN
# 10                                            Email :
# 11                                                NaN
# 12                                       2nd Holder :
# 13                                                NaN
# 14                                       3rd Holder :
# 15                                                NaN
# 16                                ARN (Latest/Last) :
# 17                                                NaN
# 18                                        Broker Name
# 19                                                NaN
# 20                                         Sub-Broker
# 21                                                NaN
# 22                                               EUIN
# 23  # It is mandatory for all  investors (new and ...
# 24  or by submitting a duly filled and signed appl...
# 25  In case there is any change in your KYC inform...
# 26                 Portfolio Summary as on 26/09/2019
# 27  Scheme Name Units Allotted Cost of Investment NAV
# 28  Motilal Oswal Multicap 35 Fund - Direct Growth...
# 29                                    Total: 3,000.00
# 30                       Detailed Transaction Summary
# 31  Scheme Motilal Oswal Multicap 35 Fund - Direct...
# 32         Date Transaction Type Amount(INR) NAV(INR)
# 33  18/07/2019 Purchase(NAV Dt.18/07/2019) 1,000.0...
# 34  16/08/2019 Purchase(NAV Dt.16/08/2019) 1,000.0...
# 35  16/09/2019 Purchase(NAV Dt.16/09/2019) 1,000.0...
# 36  Balance Units: 113.235 Pledged/Blocked Units: ...
#
#                      MUKESH SHARMA                        Unnamed: 2  \
# 0                              NaN                               NaN
# 1   H No 820 Gali No 6 Batala Road                               NaN
# 2                 New Rajesh Nagar                               NaN
# 3                         Amritsar                               NaN
# 4                           Punjab                    PIN  :  143001
# 5                              NaN                               NaN
# 6                              NaN                               NaN
# 7                              NaN                               NaN
# 8                       8054619283               Mobile : 8054619283
# 9                              NaN                               NaN
# 10     BHARDWAJ.MUKESH91@GMAIL.COM                               NaN
# 11                             NaN                               NaN
# 12                             NaN                               NaN
# 13                             NaN                               NaN
# 14                             NaN                               NaN
# 15                             NaN                               NaN
# 16                             NaN         000000-0 Advisory (RIA) :
# 17                             NaN                               NaN
# 18                               :                            DIRECT
# 19                             NaN                               NaN
# 20                               :                               NaN
# 21                             NaN                               NaN
# 22                               :                               NaN
# 23                               w  . k  a  r  v  y  mf  s . c  o  m
# 24                             NaN                               NaN
# 25                             NaN                               NaN
# 26                             NaN                               NaN
# 27                             NaN                               NaN
# 28                             NaN                               NaN
# 29                             NaN                               NaN
# 30                             NaN                               NaN
# 31                             NaN                               NaN
# 32                             NaN                             Units
# 33                             NaN                            36.790
# 34                             NaN                            38.500
# 35                             NaN                            37.945
# 36                             NaN                               NaN
#
#                                    Unnamed: 3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                               INZ000031633
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23  /  k  a  r v  y  /  f a  c  t  a  h  o  m
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                              Current Value
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
#
#                    FOLIO :91013119452  Unnamed: 5          CAN:   Unnamed: 7  \
# 0              BOID :1208160010642423         NaN        UMRN :          NaN
# 1                                 NaN         NaN           NaN          NaN
# 2    Bank Name  : STATE BANK OF INDIA         NaN           NaN          NaN
# 3                                 NaN         NaN           NaN          NaN
# 4            Bank A/c No: XXXXXXX4660         NaN     A/c Type:      SAVINGS
# 5                    Branch: AMRITSAR         NaN           NaN          NaN
# 6             Payout Type: Electronic         NaN  IFSC Code  :  SBIN0008016
# 7   Multiple Bank Reg: Not Registered         NaN    MICR Code:    143002005
# 8                                 NaN         NaN           NaN          NaN
# 9                              PAN No         NaN          CKYC          KYC
# 10                                NaN         NaN           NaN          NaN
# 11              1st Holder KSTPS1360G         NaN           NaN          NaN
# 12                                NaN         NaN           NaN          NaN
# 13                         2nd Holder         NaN           NaN          NaN
# 14                                NaN         NaN           NaN          NaN
# 15                         3rd Holder         NaN           NaN          NaN
# 16                           Guardian         NaN           NaN          NaN
# 17                           POA : NA         NaN  Nominee : 1.          NaN
# 18                                NaN         NaN           NaN          NaN
# 19                                NaN         NaN            2.          NaN
# 20                                NaN         NaN            3.          NaN
# 21                           UBO : NA         NaN           NaN          NaN
# 22           Mode of Holding : SINGLE         NaN       Status:          NaN
# 23                     e  . a  s  p x         NaN           NaN          NaN
# 24                                NaN         NaN           NaN          NaN
# 25                                NaN         NaN           NaN          NaN
# 26                                NaN         NaN           NaN          NaN
# 27                                NaN         NaN           NaN          NaN
# 28                           3,158.00         NaN           NaN          NaN
# 29                           3,158.00         NaN           NaN          NaN
# 30                                NaN         NaN           NaN          NaN
# 31                                NaN         NaN           NaN          NaN
# 32                       Unit Balance         NaN           NaN          NaN
# 33                             36.790         NaN           NaN          NaN
# 34                             75.290         NaN           NaN          NaN
# 35                            113.235         NaN           NaN          NaN
# 36                                NaN         NaN           NaN          NaN
#
#     Unnamed: 8
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9       #FATCA
# 10         NaN
# 11  Registered
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22  INDIVIDUAL
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN

# %%
df=read_pdf('/home/am/Downloads/read.pdf',multiple_tables=True)
l=[]
for i in df[1][10:13][0]:
    l.append(i.split())
    
k=0
for j in df[1][10:13][2]:
    l[k].append(j)
    k+=1
k=0
for m in df[1][10:13][4]:
    l[k].append(m)
    k+=1
print(l)
# Out:
# [['18/07/2019', 'Purchase(NAV', 'Dt.18/07/2019)', '1,000.00', '27.1814', '36.790', '36.790'], ['16/08/2019', 'Purchase(NAV', 'Dt.16/08/2019)', '1,000.00', '25.9742', '38.500', '75.290'], ['16/09/2019', 'Purchase(NAV', 'Dt.16/09/2019)', '1,000.00', '26.3536', '37.945', '113.235']]

# %%
df=read_pdf('/home/am/Downloads/read.pdf',multiple_tables=True,spreadsheet=True,)

# %%
l2=[]
   
for i in df[j][0]:
        
        l2.append(i.split('\r'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4edbf4145ab0> in <module>
#       1 l2=[]
#       2
# ----> 3 for i in df[j][0]:
#       4
#       5         l2.append(i.split('\r'))
#
# TypeError: list indices must be integers or slices, not str

# %%
df[1][0][0]
# Out:
# 'ARN (Latest/Last) :\r000000-0Advisory (RIA) :INZ000031633\rBroker Name:\rDIRECT\rSub-Broker:\rEUIN:'

# %%
df[1][0][0]
# Out:
# 'ARN (Latest/Last) :\r000000-0Advisory (RIA) :INZ000031633\rBroker Name:\rDIRECT\rSub-Broker:\rEUIN:'

# %%
for i in range(len(df[1]['data'])):
    for j in df[0]['data'][i]:
        print(j['text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-45eea2cddb30> in <module>
# ----> 1 for i in range(len(df[1]['data'])):
#       2     for j in df[0]['data'][i]:
#       3         print(j['text'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'

# %%
#for i in range(len(df[1]['data'])):
f=df[1]['data'][8][0]['text']
f
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-35fd36561027> in <module>
#       1 #for i in range(len(df[1]['data'])):
# ----> 2 f=df[1]['data'][8][0]['text']
#       3 f
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'

# %%
len(df[1]['data'][8][0]['text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-650f97595dd6> in <module>
# ----> 1 len(df[1]['data'][8][0]['text'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'data'

# %%
Name:\rMUKESH SHARMA\rAddress:\rH No 820 Gali ...
# Out:
#   File "<ipython-input-18-20d58f414ccb>", line 1
#     Name:\rMUKESH SHARMA\rAddress:\rH No 820 Gali ...
#                                                      ^
# SyntaxError: unexpected character after line continuation character

# %%
find={}
find[df1.columns[0].split()[0]]=df1.columns[1]

# %%
find
# Out:
# {'Name': 'MUKESH SHARMA'}

# %%
for i in range(len(df1['Name :'])):
    if df1['Name :'][i]=='Email :':
        find[df1['Name :'][i].split()[0]]=df1['MUKESH SHARMA'][i]

# %%
find
# Out:
# {'Name': 'MUKESH SHARMA', 'Email': 'BHARDWAJ.MUKESH91@GMAIL.COM'}

# %%
find[df1.columns[4].split()[0]]=df1.columns[4].split()[1].split(':')[1]

# %%
from tabula import read_pdf
import json
df=read_pdf('/home/am/Downloads/read.pdf', output_format='json')

# %%
df1=json.dumps(df)

# %%
import camelot

# %%
df=camelot.read_pdf('/home/am/Downloads/read.pdf')

# %%
df
# Out:
# <TableList n=1>

# %%
df[0].parsing_report
# Out:
# {'accuracy': 92.31, 'whitespace': 67.5, 'order': 1, 'page': 1}

# %%
df.export('foo.json', f='json')

# %%
df[0].df[0][0].split('\n')
# Out:
# [': :',
#  ': :',
#  'FOLIO',
#  '91013119452',
#  'CAN        ',
#  'BOID',
#  '1208160010642423',
#  'UMRN']

# %%
df=read_pdf('/home/am/Downloads/read.pdf',area=(1,1,100,400), pages='all',relative_area=True,output_format='json')

# %%
df1=pd.DataFrame(df)
df1.head()
df
# Out:
# [{'extraction_method': 'stream',
#   'top': 7.9199996,
#   'left': 6.12,
#   'width': 2441.8798828125,
#   'height': 784.0800170898438,
#   'right': 2448.0,
#   'bottom': 792.0,
#   'data': [[{'top': 48.89,
#      'left': 19.15,
#      'width': 314.17999267578125,
#      'height': 7.199999809265137,
#      'text': 'Statement of Account for Period : 18/07/2019 to 26/09/2019'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 70.12,
#      'left': 19.9,
#      'width': 339.34228515625,
#      'height': 4.7999982833862305,
#      'text': 'Name : MUKESH SHARMA FOLIO :91013119452'},
#     {'top': 70.12,
#      'left': 420.4,
#      'width': 41.08000183105469,
#      'height': 4.7999982833862305,
#      'text': 'CAN:'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 83.62,
#      'left': 280.9,
#      'width': 99.22225952148438,
#      'height': 4.7999982833862305,
#      'text': 'BOID :1208160010642423'},
#     {'top': 83.62,
#      'left': 420.4,
#      'width': 41.08000183105469,
#      'height': 4.7999982833862305,
#      'text': 'UMRN :'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 90.37,
#      'left': 19.9,
#      'width': 155.10000610351562,
#      'height': 4.7999982833862305,
#      'text': 'Address :  H No 820 Gali No 6 Batala Road'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 97.79,
#      'left': 67.9,
#      'width': 336.8699951171875,
#      'height': 7.449999809265137,
#      'text': 'New Rajesh Nagar Bank Name  : STATE BANK OF INDIA'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 111.18,
#      'left': 67.9,
#      'width': 30.77999496459961,
#      'height': 4.130000114440918,
#      'text': 'Amritsar'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 120.29,
#      'left': 67.9,
#      'width': 310.8522644042969,
#      'height': 5.100001335144043,
#      'text': 'PunjabPIN  :  143001 Bank A/c No: XXXXXXX4660'},
#     {'top': 120.29,
#      'left': 420.4,
#      'width': 41.062255859375,
#      'height': 4.130000114440918,
#      'text': 'A/c Type:'},
#     {'top': 120.29,
#      'left': 466.9,
#      'width': 29.610008239746094,
#      'height': 4.130000114440918,
#      'text': 'SAVINGS'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 130.79,
#      'left': 280.9,
#      'width': 85.64999389648438,
#      'height': 4.130000114440918,
#      'text': 'Branch: AMRITSAR'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 141.29,
#      'left': 280.9,
#      'width': 84.0770263671875,
#      'height': 4.130000114440918,
#      'text': 'Payout Type: Electronic'},
#     {'top': 141.29,
#      'left': 420.4,
#      'width': 40.392242431640625,
#      'height': 4.130000114440918,
#      'text': 'IFSC Code  :'},
#     {'top': 141.29,
#      'left': 466.15,
#      'width': 46.74000549316406,
#      'height': 4.130000114440918,
#      'text': 'SBIN0008016'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 151.79,
#      'left': 280.9,
#      'width': 121.44223022460938,
#      'height': 4.130000114440918,
#      'text': 'Multiple Bank Reg: Not Registered'},
#     {'top': 151.79,
#      'left': 420.4,
#      'width': 40.842254638671875,
#      'height': 4.130000114440918,
#      'text': 'MICR Code:'},
#     {'top': 151.79,
#      'left': 466.15,
#      'width': 37.56999206542969,
#      'height': 4.130000114440918,
#      'text': '143002005'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 157.87,
#      'left': 19.9,
#      'width': 203.74000549316406,
#      'height': 4.7999982833862305,
#      'text': 'Phone : 8054619283 Mobile : 8054619283'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 163.79,
#      'left': 343.65,
#      'width': 27.462249755859375,
#      'height': 4.130000114440918,
#      'text': 'PAN No'},
#     {'top': 163.79,
#      'left': 407.77,
#      'width': 18.452239990234375,
#      'height': 4.130000114440918,
#      'text': 'CKYC'},
#     {'top': 163.79,
#      'left': 465.15,
#      'width': 13.99749755859375,
#      'height': 4.130000114440918,
#      'text': 'KYC'},
#     {'top': 163.78,
#      'left': 513.4,
#      'width': 26.079965591430664,
#      'height': 4.130000114440918,
#      'text': '#FATCA'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 170.62,
#      'left': 19.9,
#      'width': 175.57000732421875,
#      'height': 4.7999982833862305,
#      'text': 'Email : BHARDWAJ.MUKESH91@GMAIL.COM'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 175.79,
#      'left': 280.9,
#      'width': 95.07098388671875,
#      'height': 4.130000114440918,
#      'text': '1st Holder KSTPS1360G'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 175.94,
#      'left': 513.53,
#      'width': 30.299943923950195,
#      'height': 3.5,
#      'text': 'Registered'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 183.37,
#      'left': 19.9,
#      'width': 44.08000183105469,
#      'height': 4.7999982833862305,
#      'text': '2nd Holder :'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 189.29,
#      'left': 280.9,
#      'width': 38.030006408691406,
#      'height': 4.130000114440918,
#      'text': '2nd Holder'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 196.87,
#      'left': 19.9,
#      'width': 44.08000183105469,
#      'height': 4.7999982833862305,
#      'text': '3rd Holder :'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 203.54,
#      'left': 280.9,
#      'width': 36.540016174316406,
#      'height': 4.130000114440918,
#      'text': '3rd Holder'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 216.29,
#      'left': 19.9,
#      'width': 292.5999755859375,
#      'height': 7.130000114440918,
#      'text': 'ARN (Latest/Last) : 000000-0 Advisory (RIA) : INZ000031633 Guardian'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 229.12,
#      'left': 280.9,
#      'width': 34.951629638671875,
#      'height': 4.7999982833862305,
#      'text': 'POA : NA'},
#     {'top': 229.12,
#      'left': 412.15,
#      'width': 50.38999938964844,
#      'height': 4.8100080490112305,
#      'text': 'Nominee : 1.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 232.87,
#      'left': 19.9,
#      'width': 95.31000518798828,
#      'height': 4.7999982833862305,
#      'text': 'Broker Name : DIRECT'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 238.22,
#      'left': 455.65,
#      'width': 6.889997482299805,
#      'height': 3.5,
#      'text': '2.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 247.12,
#      'left': 19.9,
#      'width': 66.81412506103516,
#      'height': 4.7999982833862305,
#      'text': 'Sub-Broker :'},
#     {'top': 247.22,
#      'left': 455.65,
#      'width': 6.889997482299805,
#      'height': 3.5,
#      'text': '3.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 253.9,
#      'left': 280.9,
#      'width': 34.09000778198242,
#      'height': 4.7699995040893555,
#      'text': 'UBO : NA'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 261.37,
#      'left': 19.9,
#      'width': 353.30224609375,
#      'height': 7.800013542175293,
#      'text': 'EUIN : Mode of Holding : SINGLE'},
#     {'top': 265.04,
#      'left': 447.4,
#      'width': 24.27099609375,
#      'height': 4.130000114440918,
#      'text': 'Status:'},
#     {'top': 265.04,
#      'left': 478.9,
#      'width': 39.8900146484375,
#      'height': 4.130000114440918,
#      'text': 'INDIVIDUAL'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 277.55,
#      'left': 15.4,
#      'width': 445.4200134277344,
#      'height': 3.8099987506866455,
#      'text': '# It is mandatory for all  investors (new and existing) to provide information related to FATCA (Foreign Account Tax Compliance Act). These details can be updated online at  h  t  t p  s  : /  /  w'},
#     {'top': 277.55,
#      'left': 460.82,
#      'width': 4.28000020980835,
#      'height': 3.0,
#      'text': 'w'},
#     {'top': 277.55,
#      'left': 465.11,
#      'width': 39.860008239746094,
#      'height': 3.8099987506866455,
#      'text': 'w. k  a  r  v  y  mf  s . c  o  m'},
#     {'top': 277.55,
#      'left': 504.96,
#      'width': 40.96001434326172,
#      'height': 3.8099987506866455,
#      'text': '/  k  a  r v  y  /  f a  c  t  a  h  o  m'},
#     {'top': 277.55,
#      'left': 545.91,
#      'width': 15.470056533813477,
#      'height': 3.8099987506866455,
#      'text': 'e  . a  s  p x'}],
#    [{'top': 285.71,
#      'left': 15.4,
#      'width': 192.52999877929688,
#      'height': 3.0299999713897705,
#      'text': 'or by submitting a duly filled and signed application form at any of our branch.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 296.6,
#      'left': 15.4,
#      'width': 497.9700012207031,
#      'height': 3.0299999713897705,
#      'text': 'In case there is any change in your KYC information please update the same by using the prescribed ‘KYC change request form’ and submit the same at the Point of Service of any KYC Registration Agency.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 313.0,
#      'left': 15.9,
#      'width': 138.4099884033203,
#      'height': 4.5,
#      'text': 'Portfolio Summary as on 26/09/2019'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 328.02,
#      'left': 113.78,
#      'width': 300.6822509765625,
#      'height': 4.130000114440918,
#      'text': 'Scheme Name Units Allotted Cost of Investment'},
#     {'top': 328.02,
#      'left': 448.8,
#      'width': 16.232269287109375,
#      'height': 4.130000114440918,
#      'text': 'NAV'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 328.02,
#      'left': 497.7,
#      'width': 47.470008850097656,
#      'height': 4.130000114440918,
#      'text': 'Current Value'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 341.66,
#      'left': 15.65,
#      'width': 378.6709899902344,
#      'height': 3.5,
#      'text': 'Motilal Oswal Multicap 35 Fund - Direct Growth Option 113.235 3,000.00'},
#     {'top': 341.66,
#      'left': 445.05,
#      'width': 23.800994873046875,
#      'height': 3.5,
#      'text': '27.8889'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 341.66,
#      'left': 511.8,
#      'width': 24.760032653808594,
#      'height': 3.5,
#      'text': '3,158.00'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 352.67,
#      'left': 18.01,
#      'width': 377.9180908203125,
#      'height': 4.249995231628418,
#      'text': 'Total: 3,000.00'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 352.79,
#      'left': 508.8,
#      'width': 29.370012283325195,
#      'height': 4.130000114440918,
#      'text': '3,158.00'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 367.46,
#      'left': 15.4,
#      'width': 114.84000396728516,
#      'height': 4.5,
#      'text': 'Detailed Transaction Summary'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 380.1,
#      'left': 19.9,
#      'width': 317.6200256347656,
#      'height': 4.130000114440918,
#      'text': 'Scheme Motilal Oswal Multicap 35 Fund - Direct Growth- ISIN No : INF247L01502 (Demat)'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 393.67,
#      'left': 15.4,
#      'width': 408.39227294921875,
#      'height': 4.880000114440918,
#      'text': 'Date Transaction Type Amount(INR)'},
#     {'top': 394.42,
#      'left': 429.17,
#      'width': 33.62225341796875,
#      'height': 4.130000114440918,
#      'text': 'NAV(INR)'},
#     {'top': 394.42,
#      'left': 485.16,
#      'width': 18.892242431640625,
#      'height': 4.130000114440918,
#      'text': 'Units'},
#     {'top': 394.42,
#      'left': 516.76,
#      'width': 43.329994201660156,
#      'height': 4.130000114440918,
#      'text': 'Unit Balance'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 406.63,
#      'left': 15.4,
#      'width': 407.5574951171875,
#      'height': 4.760009765625,
#      'text': '18/07/2019 Purchase(NAV Dt.18/07/2019) 1,000.00'},
#     {'top': 407.64,
#      'left': 431.02,
#      'width': 25.4468994140625,
#      'height': 3.75,
#      'text': '27.1814'},
#     {'top': 407.05,
#      'left': 486.33,
#      'width': 18.09625244140625,
#      'height': 3.130000114440918,
#      'text': '36.790'},
#     {'top': 407.05,
#      'left': 542.73,
#      'width': 17.39004135131836,
#      'height': 3.130000114440918,
#      'text': '36.790'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 418.87,
#      'left': 15.4,
#      'width': 407.5574951171875,
#      'height': 4.75,
#      'text': '16/08/2019 Purchase(NAV Dt.16/08/2019) 1,000.00'},
#     {'top': 419.87,
#      'left': 431.02,
#      'width': 25.4468994140625,
#      'height': 3.75,
#      'text': '25.9742'},
#     {'top': 419.28,
#      'left': 486.33,
#      'width': 18.09625244140625,
#      'height': 3.130000114440918,
#      'text': '38.500'},
#     {'top': 419.28,
#      'left': 542.73,
#      'width': 17.39004135131836,
#      'height': 3.130000114440918,
#      'text': '75.290'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 431.1,
#      'left': 15.4,
#      'width': 407.5574951171875,
#      'height': 4.759979248046875,
#      'text': '16/09/2019 Purchase(NAV Dt.16/09/2019) 1,000.00'},
#     {'top': 432.11,
#      'left': 431.02,
#      'width': 25.4468994140625,
#      'height': 3.75,
#      'text': '26.3536'},
#     {'top': 431.52,
#      'left': 486.33,
#      'width': 18.09625244140625,
#      'height': 3.130000114440918,
#      'text': '37.945'},
#     {'top': 431.52,
#      'left': 539.57,
#      'width': 20.54000473022461,
#      'height': 3.130000114440918,
#      'text': '113.235'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 444.11,
#      'left': 15.4,
#      'width': 549.0099487304688,
#      'height': 4.230010986328125,
#      'text': 'Balance Units: 113.235 Pledged/Blocked Units: 0.000 Free Units: 113.235 NAV as on 31-Jan-2018 Rs. 28.3096 (For long term capital gains calculation)'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 459.23,
#      'left': 15.4,
#      'width': 519.5000610351562,
#      'height': 4.0,
#      'text': 'Current Load Structure: Entry Load: Nil, Exit Load: For subscriptions received w.e.f. November 01,2018, 1%- If redeemed on or before 15 days from the date of'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 469.0,
#      'left': 97.9,
#      'width': 457.3700256347656,
#      'height': 4.0,
#      'text': 'allotment. Nil- If redeemed after 15 days fromthe date of allotment. A switch-out or a withdrawal shall also be subjected to the Exit load like'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 478.76,
#      'left': 97.9,
#      'width': 449.6399841308594,
#      'height': 4.0,
#      'text': 'any redemption. Redemption, Switch and Systematic Withdrawal of units would bedone on First in First out basis (FIFO). For subscriptions'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 488.53,
#      'left': 97.9,
#      'width': 436.8000183105469,
#      'height': 4.0,
#      'text': 'prior to November 01, 2018, shall continue to be subject to the load structure as may have been applicable at the time oftheir original'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 498.29,
#      'left': 97.9,
#      'width': 458.08001708984375,
#      'height': 4.0,
#      'text': 'Investments. For Special Products registrations, load for each transaction is based on the load structure applicable as of the registration date.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 776.35,
#      'left': 119.2,
#      'width': 76.05999755859375,
#      'height': 1.5,
#      'text': 'CA : HY03-ADMIN-27.09.2019 / LA: DMTCONF-27.09.19-3'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 778.54,
#      'left': 424.46,
#      'width': 36.130523681640625,
#      'height': 3.869999885559082,
#      'text': 'Page 1'},
#     {'top': 778.54,
#      'left': 463.15,
#      'width': 21.010000228881836,
#      'height': 3.869999885559082,
#      'text': 'OF 2'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}]]},
#  {'extraction_method': 'stream',
#   'top': 7.9199996,
#   'left': 6.12,
#   'width': 2441.8798828125,
#   'height': 784.0800170898438,
#   'right': 2448.0,
#   'bottom': 792.0,
#   'data': [[{'top': 48.89,
#      'left': 19.15,
#      'width': 314.17999267578125,
#      'height': 7.199999809265137,
#      'text': 'Statement of Account for Period : 18/07/2019 to 26/09/2019'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 429.22,
#      'left': 15.4,
#      'width': 333.6300048828125,
#      'height': 3.0,
#      'text': 'Download our new Mobile App to track your portfolio, invest more with us, send your queries, download reports, etc. Download for A'},
#     {'top': 429.22,
#      'left': 349.03,
#      'width': 149.13998413085938,
#      'height': 3.0,
#      'text': 'ndroid Devices (Google Play) and Apple Devices (App store)'}],
#    [{'top': 440.8,
#      'left': 15.4,
#      'width': 391.3180236816406,
#      'height': 3.0,
#      'text': 'This is a computer generated statement and does not require signature. Incase of any queries kindly contact us on 81086 22222 or 022-4054 8002 or write us on'},
#     {'top': 440.8,
#      'left': 409.15,
#      'width': 71.9800033569336,
#      'height': 3.0,
#      'text': 'mfservice@motilaloswal.com'}],
#    [{'top': 447.35,
#      'left': 296.4,
#      'width': 34.18001174926758,
#      'height': 2.5,
#      'text': 'Please Tear Here'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 455.9,
#      'left': 282.52,
#      'width': 52.610008239746094,
#      'height': 4.0,
#      'text': 'Transaction Slip'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 466.47,
#      'left': 15.4,
#      'width': 255.91001892089844,
#      'height': 4.499995231628418,
#      'text': 'Folio No. : 91013119452 Transaction in Scheme *Scheme Name'},
#     {'top': 466.47,
#      'left': 357.74,
#      'width': 167.86001586914062,
#      'height': 3.25,
#      'text': 'PlanOption'}],
#    [{'top': 480.38,
#      'left': 15.4,
#      'width': 248.67227172851562,
#      'height': 4.130000114440918,
#      'text': 'Mode of Holding: SINGLE Broker Code: 000000-0'},
#     {'top': 480.38,
#      'left': 348.4,
#      'width': 155.04002380371094,
#      'height': 4.130000114440918,
#      'text': 'Sub Broker: EUIN:'}],
#    [{'top': 495.45,
#      'left': 168.9,
#      'width': 188.29226684570312,
#      'height': 4.130000114440918,
#      'text': 'Investor Name PAN No.'},
#     {'top': 495.45,
#      'left': 397.27,
#      'width': 142.92002868652344,
#      'height': 4.130000114440918,
#      'text': 'CKYC KYC FATCA'}],
#    [{'top': 506.71,
#      'left': 17.56,
#      'width': 343.0409851074219,
#      'height': 3.75,
#      'text': '1st Holder MUKESH SHARMA KSTPS1360G'},
#     {'top': 506.89,
#      'left': 514.23,
#      'width': 30.300004959106445,
#      'height': 3.5,
#      'text': 'Registered'}],
#    [{'top': 518.68,
#      'left': 16.9,
#      'width': 34.209999084472656,
#      'height': 3.75,
#      'text': '2nd Holder'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 531.43,
#      'left': 16.9,
#      'width': 32.7599983215332,
#      'height': 3.75,
#      'text': '3rd Holder'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 544.18,
#      'left': 16.15,
#      'width': 28.76999855041504,
#      'height': 3.75,
#      'text': 'Guardian'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 557.68,
#      'left': 16.9,
#      'width': 33.35987854003906,
#      'height': 4.16998291015625,
#      'text': 'POA  : NA'},
#     {'top': 557.82,
#      'left': 433.9,
#      'width': 33.91999816894531,
#      'height': 4.489985466003418,
#      'text': 'UBO : NA'}],
#    [{'top': 573.63,
#      'left': 16.19,
#      'width': 74.88999938964844,
#      'height': 4.5,
#      'text': 'Additional Purchase'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 586.98,
#      'left': 15.4,
#      'width': 318.4922790527344,
#      'height': 4.130000114440918,
#      'text': 'Amount (Rs): Payment Mode (Cheque/DD, RTGS/NEFT, Fund Transfer):'},
#     {'top': 586.98,
#      'left': 429.4,
#      'width': 67.42000579833984,
#      'height': 4.130000114440918,
#      'text': 'Cheque/DD/UTR No'}],
#    [{'top': 600.28,
#      'left': 15.4,
#      'width': 345.7809753417969,
#      'height': 4.399958610534668,
#      'text': 'A/c Type (Savings / Current / NRE / NRO / FCNR) Payment Bank A/c No.'},
#     {'top': 599.1,
#      'left': 362.65,
#      'width': 131.9600067138672,
#      'height': 5.580012321472168,
#      'text': '# Dated'}],
#    [{'top': 614.87,
#      'left': 15.4,
#      'width': 342.8999938964844,
#      'height': 4.130000114440918,
#      'text': 'Bank Name Branch:'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 626.73,
#      'left': 15.4,
#      'width': 263.1600036621094,
#      'height': 2.880000114440918,
#      'text': '# Payment should be from the bank account of first holder only. Third Party payments are not accepted.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 640.89,
#      'left': 16.15,
#      'width': 57.339996337890625,
#      'height': 4.5,
#      'text': 'Switch Request'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 655.39,
#      'left': 15.4,
#      'width': 311.4622497558594,
#      'height': 6.279963493347168,
#      'text': 'Switch In * Scheme NamePlanOption Rs.'},
#     {'top': 657.54,
#      'left': 411.4,
#      'width': 129.6999969482422,
#      'height': 4.130000114440918,
#      'text': 'Units OR All Units'}],
#    [{'top': 669.13,
#      'left': 16.9,
#      'width': 285.5899963378906,
#      'height': 4.609980583190918,
#      'text': '* Mandatory, else transactions may be rejected. Please specify scheme/plan/option in the space above clearly.'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 685.04,
#      'left': 15.4,
#      'width': 78.54000091552734,
#      'height': 4.5,
#      'text': 'Redemption Request'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 696.03,
#      'left': 15.4,
#      'width': 305.5899963378906,
#      'height': 6.289973258972168,
#      'text': 'Please redeem Rs. (in fig)(in words)'},
#     {'top': 694.4,
#      'left': 384.4,
#      'width': 147.6999969482422,
#      'height': 4.8800048828125,
#      'text': 'ORUni t sOR All Units'}],
#    [{'top': 713.75,
#      'left': 15.9,
#      'width': 546.2000122070312,
#      'height': 3.0,
#      'text': 'I/We have read and understood the contents of the Scheme Information Document and Statement  of Additional Information, Key Information Memorandum,  Addendum and Instructions issued of respective Scheme(s)  of'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 721.08,
#      'left': 15.9,
#      'width': 545.8400268554688,
#      'height': 3.0,
#      'text': 'Motilal  Oswal Mutual Fund. I/We hereby apply to the trustee of Motilal  Oswal Mutual Fund for units  of the Scheme(s) and agree to abide  by the terms and conditions, rules and regulations of the relevant Scheme(s).  I/We'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 728.4,
#      'left': 15.9,
#      'width': 266.0500183105469,
#      'height': 3.0,
#      'text': 'have neither received nor been induced by any rebate or gifts, directly or indirectly in making this investment'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 740.61,
#      'left': 15.4,
#      'width': 327.4602355957031,
#      'height': 4.5,
#      'text': 'Signatures 1st Holder 2nd Holder'},
#     {'top': 741.83,
#      'left': 489.53,
#      'width': 32.469970703125,
#      'height': 3.25,
#      'text': '3rd Holder'}],
#    [{'top': 755.44,
#      'left': 95.65,
#      'width': 103.36000061035156,
#      'height': 3.0,
#      'text': '(All holders to sign in case of joint holding)'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 767.33,
#      'left': 478.9,
#      'width': 66.64000701904297,
#      'height': 4.130000114440918,
#      'text': 'PTO for instructions'}],
#    [{'top': 777.02,
#      'left': 119.2,
#      'width': 76.05999755859375,
#      'height': 1.5,
#      'text': 'CA : HY03-ADMIN-27.09.2019 / LA: DMTCONF-27.09.19-3'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 779.21,
#      'left': 424.46,
#      'width': 59.70000076293945,
#      'height': 3.869999885559082,
#      'text': 'Page 2 OF 2'}]]}]

# %%
data={"state":"Uttarakhand",
       "City":"Haridwar",
       "AUN":"24 Lac",
       "age":24,
      "specialization":"Mutual Fund",
      'experience':10
     }

# %%
with open('data.json', 'w') as json_file:
    json.dump(data, json_file)

# %%
f = json.loads(open('/home/am/python/data.json').read())

# %%
with open('output.json', 'w') as json_file:
    json.dump(advisor, json_file)

# %%
advisor={
    "item": {
        "advisors": [
            {
                "id": 1,
                "Name": "Mukesh Bhardwaj",
                "Gender": "Male",
                "city": "Rampur",
                "Experience": "7",
                "state": "Uttar Pradesh"
            },
            {
                "id": 2,
                "Name": "Aniska Sexsena",
                "Gender": "Female",
                "city": "Haridwar",
                "Experience": "8",
                "state": "Uttarakhand"
            }
        ]
    }
}

# %%
for i in range(len(advisor['item']["advisors"])):
    for j in advisor['item']["advisors"][i]:
        if advisor['item']["advisors"][i]['state']==state and advisor['item']["advisors"][i]['city']==city:
            print(advisor['item']["advisors"][i]['Name'])
            break

# %%
for j in advisor['item']["advisors"][0]:
    if j=='city':
        
        print(advisor['item']["advisors"][0]['city'])

# %%
advisor['item']["advisors"][0]['Experience']

# %%
state='Uttar Pradesh'
city='Rampur'
Experience=8
ex=[5,6,7,8,9,10]

# %%
for i in range(len(advisor['item']["advisors"])):
    if int(advisor['item']["advisors"][i]['Experience']) in ex:
        print(advisor['item']["advisors"][i]['Experience'])

# %%
advisor['item']["advisors"][0]['Experience']  in ex

# %%
advisor['item']["advisors"][0]['Experience']

# %%
advisor={
    "item": {
        "advisors": [
            {
                "id": 1,
                "Name": "Mukesh Bhardwaj",
                "Gender": "Male",
                "city": "Rampur",
                "Experience": "7",
                "state": "Uttar Pradesh"
            },
            {
                "id": 2,
                "Name": "Aniska Sexsena",
                "Gender": "Female",
                "city": "Haridwar",
                "Experience": "8",
                "state": "Uttarakhand"
            }
        ]
    }
}

# %%
output_data = {}
output_data['advisors'] = []
id=1
for i in range(len(advisor['item']["advisors"])):
    for j in advisor['item']["advisors"][i]:
        if int(advisor['item']["advisors"][i]['Experience']) in ex:
            data = {}
            data['id']=id
            data['Name'] = advisor['item']["advisors"][i]['Name']
            data['Gender'] = advisor['item']["advisors"][i]['Gender']
            data['Experience'] = advisor['item']["advisors"][i]['Experience']
            data['State'] = advisor['item']["advisors"][i]['state']
            data['city'] = advisor['item']["advisors"][i]['city']
            output_data['advisors'].append(data)
            id+=1
            break

# %%
output_data

# %%
a['ad'].append({'name':'atul'})

# %%
a

# %%
import pymongo

# %%
# !pip install --user pymongo

# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb['Advisor_data']

# %%
if data in mycol.find():
    print('collection data already exists')
else:
    insrt=mycol.insert_one(advisor)
    print('successfully inserted')

# %%
f=mycol.find_one({},{'item':1,'_id':0})

# %%
advisor=mycol.find_one({},{'_id':0})
advisor

# %%
output={}
output['item']=[]
for i in range(4):
    data={}
    name,age,ex,state,city=input('enter seperated by (,): ').split(',')
    data['name']=name
    data['age']=age
    data['Expereince']=ex
    data['State']=state
    data['city']=city
    output['item'].append(data)

# %%
output

# %%
from tabula import read_pdf

df=read_pdf('/home/am/Downloads/read.pdf',area=(1,1,100,400), pages='all',relative_area=True,output_format='json')

# %%
data=[]
for i in range(len(df[0]['data'])):
    for j in range(len(df[0]['data'][i])):
        data.append(df[0]['data'][i][j]['text'])
        print(df[0]['data'][i][j]['text'].strip("   "))

# %%
data

# %%
data=list(dict.fromkeys(data))

# %%
data.remove('')

# %%
data

# %%
for i in data:
    if 'Name' in i or 'Email' in i :
        print(i)

# %%
for i in data:
    if 'Balance Units' in i:
        break

    if i=='Unit Balance':
        continue
    print(i)

# %%
a={ "item" : [ { "id" : 1, "name" : "Dharmendra Singh", "State" : "Uttar Paradesh", "City" : "Moradabad" }, { "id" : 2, "Name" : "Mohd Junaid", "State" : "Uttar Pradesh", "City" : "Amroha" } ] }

# %%
a

# %%
a['item'][0]['name']

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
url=input('Enter URL or Paste here: ')
page=requests.get(url).text
soup=BeautifulSoup(page,'html.parser')
data=soup.find('table',{'class':'fund-snapshot-port-holdings-equity'})
table=[]
for rows in data.find_all('tr'):
    cols=rows.find_all('td')
    if len(cols)==7:
        dat=[]
        table.append(dat)
        for i in range(len(cols)):
            if i==0:
                continue
            dat.append(cols[i].text.strip())
col_name=[]
for th in data.find_all('tr'):
    name=th.find_all('th')
    if len(name)==7:
        for i in range(len(name)):
            if i==0:
                continue            
            col_name.append(name[i].text.strip())
    #col.append(name[0].text.strip())
#print(col_name)
df=pd.DataFrame(table, columns=col_name)
df=df.apply(pd.to_numeric ,errors='ignore')
file_name=input('Enter File Name To Save: ')
df.to_csv(f'{file_name}.csv')
#df.info()
#df.head()

# %%
df.head()

# %%
for rows in data.find_all('tr'):
    cols=rows.find_all('td')
    if len(cols)==7:
        for i in range(len(cols)):
            if i==0:
                continue
            print(cols[i].text)
                #dat.append(cols[i].text.strip())

# %%
for th in data.find_all('tr'):
    name=th.find_all('th')
    if len(name)==7:
        
        print(name[2].text)

# %%
url='https://www.valueresearchonline.com/funds/newsnapshot.asp?schemecode=10594&utm_source=direct-click&utm_medium=funds&utm_term=&utm_content=Kotak+Standard+Multicap+Reg&utm_campaign=vro-search'

# %%
a=url.split('m_content=')
b=a[1].split('&utm_campaign=vro-search')
c=b[0].replace('+'," ")
c

# %%
b=a[1].split('&utm_campaign=vro-search')
c=b[0].replace('+'," ")
c

# %%
import requests
from bs4 import BeautifulSoup
url_all='https://www.valueresearchonline.com/funds/fundSelector/default.asp?myport=&amc=4%2C8799%2C5%2C312%2C332%2C8%2C181%2C339%2C8927%2C28%2C302%2C308%2C14%2C9023%2C298%2C9636%2C9655%2C319%2C12232%2C19%2C218%2C185%2C21%2C11141%2C327%2C9054%2C24%2C9055%2C10157%2C15%2C11%2C317%2C186%2C25%2C26%2C187%2C27%2C10%2C9521%2C311%2C12160&cat=equityAll%2CdebtsAll%2ChybridAll%2C100%2C101%2C102%2C103%2C104%2C105%2C106%2C107%2C108%2C109%2C110%2C111%2C112%2C113%2C114%2C115%2C116%2C117%2C118%2C119%2C120%2C121%2C122%2C123%2C124%2C125%2C126%2C127%2C128%2C129%2C130%2C131%2C132%2C133%2C134%2C135%2C136%2C137%2C139%2C140%2C141%2C142%2C143%2C144&exc=&isTabChng=1&pg=#'

page=requests.get(url_all).text
soup=BeautifulSoup(page,'html.parser')
data=soup.find('div',{'class':'pull-left'})
links=[]
for rows in data.find_all('tr'):
    cols=rows.find_all('td')
    if len(cols)==9:
        for i in cols:
            c=i.find('a')
            try:
                if c.get('href')[0:4]!='/pdf':
                    links.append('https://www.valueresearchonline.com'+c.get('href'))
            except:

                break
df=pd.DataFrame(links,columns=['links'])
df.to_csv('MutualFundLinks.csv')

# %%
len(links)

# %%
# Find Name of Mutual Fund

import requests
from bs4 import BeautifulSoup
url = "https://www.valueresearchonline.com/funds/newsnapshot.asp?schemecode=37631"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
#a=soup.title.text
#a.split(a[a.index(':'):])[0].rstrip()
soup.title.text.split(soup.title.text[soup.title.text.index(':'):])[0].rstrip()

# %%
df=pd.read_csv('MutualFundLinks.csv')

# %%
for url in df['links']:
    print(url)
    break

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
url=input('Enter URL or Paste here: ')
page=requests.get(url).text
soup=BeautifulSoup(page,'html.parser')

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
url=input('Enter URL or Paste here: ')
page=requests.get(url).text
soup=BeautifulSoup(page,'html.parser')

def Hybrid_and_Debt_Data():
    data=soup.find('table',{'class':'fund-snapshot-port-holdings-other'})
    file_name = soup.title.text.split(soup.title.text[soup.title.text.index(':'):])[0].rstrip()
    table=[]
    col_name=[]
    try:
        for rows in data.find_all('tr'):
            cols=rows.find_all('td')
            if len(cols)>=6:
                dat=[]
                table.append(dat)
                for i in range(len(cols)):
                    if i==0:
                        continue
                    dat.append(cols[i].text.strip())
        for th in data.find_all('tr'):
            name=th.find_all('th')
            if len(name)==6:
                for i in range(len(name)):
                    if i==0:
                        continue            
                    col_name.append(name[i].text.strip())
    except:
        pass
    return table, col_name, file_name


def EquityData():
    data=soup.find('table',{'class':'fund-snapshot-port-holdings-equity'})
    file_name = soup.title.text.split(soup.title.text[soup.title.text.index(':'):])[0].rstrip()
    table=[]
    col_name=[]
    try:
        for rows in data.find_all('tr'):
            cols=rows.find_all('td')
            if len(cols)>=6:
                dat=[]
                table.append(dat)
                for i in range(len(cols)):
                    if i==0:
                        continue
                    dat.append(cols[i].text.strip())
        for th in data.find_all('tr'):
            name=th.find_all('th')
            if len(name)==7:
                for i in range(len(name)):
                    if i==0:
                        continue            
                    col_name.append(name[i].text.strip())
    except:
        pass

    
    return table, col_name, file_name

# %%
def final():
    NoData=[]
    hybrid, col_name, file_name = Hybrid_and_Debt_Data()
    Equity, col_nameE, file_name= EquityData()   
    if len(Equity)>=5 and len(hybrid)>=5:
        df=pd.DataFrame(Equity, columns=col_nameE)
        df.to_csv(file_name+'Equity.csv')
        df1=pd.DataFrame(hybrid, columns=col_name)
        df1.to_csv(file_name+'hybrid.csv')
    elif len(hybrid)>=5:
        df1=pd.DataFrame(hybrid, columns=col_name)
        df1.to_csv(file_name+'hybrid.csv')
    else:
        NoData.append(url)
        print(f"No mutual fund found in {file_name}")
        return NoData

# %%
def NoData():
    NoData=final()
    df=pd.DataFrame(NoData, columns=['No_Data'])
    df.to_csv('No_Data_Url.csv')

# %%
NoData()

# %%
data=soup.find('table',{'class':'fund-snapshot-port-holdings-other'})
col_name=[]
for th in data.find_all('tr'):
        name=th.find_all('th')
        if len(name)==6:
            for i in range(len(name)):
                if i==0:
                    continue            
                col_name.append(name[i].text.strip())

# %%
a=[]
col='name'
name='Dharmendra'
for i in range(2):
    a.append([col,name])

# %%
df=pd.read_csv('~/PycharmProjects/ScrapeMutualFundData/Downloads/MutualFundLinks.csv')

# %%
import os, requests

# %%
print(os.getcwd())

# %%
os.path

# %%
import pandas
import json

# %%
os.path.abspath('pandas')

# %%
len(os.listdir())

# %%
response = requests.get("http://api.open-notify.org/astros.json")

print(response.status_code)

# %%
data = response.json()

# %%
import csv
row = ['2', ' Marie', ' California']

with open('people.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerow(row)
writeFile.close()

# %%
import csv
row = ['4', ' Danny', ' New York']
with open('people1.csv', 'a') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(row)
csvFile.close()

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
url='https://www.valueresearchonline.com/funds/portfoliovr.asp?schemecode=15739'
page=requests.get(url).text
soup=BeautifulSoup(page,'html.parser')
data=soup.find('table',{'class':'fund-snapshot-port-holdings-equity'})

# %%
data.th.text.split()[1]

# %%
for rows in data1.find_all('tr'):
    
    cols = rows.find_all('td')
    if len(cols) >= 6:
        dat = []
        for i in range(len(cols)):
            if i == 0:
                continue
            dat.append(cols[i].text.strip())
        if data1.th.text.split()[1]=='Debt':
            with open('DebtTest.csv', 'a') as csvFile:
                writer = csv.writer(csvFile)
                writer.writerow(dat)
        elif data1.th.text.split()[1]!='Debt':
            with open('HybridTest.csv', 'a') as csvFile:
                writer = csv.writer(csvFile)
                writer.writerow(dat)

# %%
import time
from IPython.display import clear_output
while True:
    localtime=time.localtime()
    result = time.strftime('%I:%M:%S:%p',localtime)
    #clear_output()
    print(result, end="")
    print('\r', end="")
    time.sleep(1)

# %%
print('\r', end="", flush=True)

# %%
print(result, end="", flush=True)
print('\r', end="", flush=True)

# %%
for i in range(10):
    print(i, end='' ,flush=True)
    print('\r', end='')

# %%
import os

# %%
os.getcwd()

# %%
path=r'/home/am/python/Mutual Fund Data/DebtTest.csv'

# %%
print(os.stat(path).st_size)

# %%
def convert_bytes(num):
    """
    this function will convert bytes to MB.... GB... etc
    """
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return "%3.1f %s" % (num, x)
        num /= 1024.0


def file_size(file_path):
    """
    this function will return the file size
    """
    if os.path.isfile(file_path):
        file_info = os.stat(file_path)
        return convert_bytes(file_info.st_size)

# %%
file_size(path)

# %%
path=r'/home/am/python/Mutual Fund Data/'
os.listdir(path)

# %%
for i,j,k in os.walk(path):
    print()

# %%
os.path.dirname(os.path.realpath(__file__))

# %%
while True:
    size=0

# %%
size=0
for i in os.listdir(path):
    if i.endswith('.csv'):
        if i.endswith('Links.csv'):
            continue
        a=path+'/'+i
        print(file_size(a))

# %%
while True:
    size=0
    for i in os.listdir(path):
        if i.endswith('.csv'):
            if i.endswith('Links.csv'):
                continue
            a=path+'/'+i
            siz=file_size(a).split(' ')
            if siz[1]=='KB':
                siz[0]=float(siz[0])/1025

            size=size+float(siz[0])
    print(f"{'%.9f' % size} MB", end='',flush=True)
    print('\r', end='', flush=True)

# %%
size+float(size[0])

# %%
import os
path=r'/home/am/python/Mutual Fund Data/'
while True:
    size=0
    for i in os.listdir(path):
        if i.endswith('.csv'):
            if i.endswith('Links.csv'):
                continue
            a=path+'/'+i
            siz=file_size(a).split(' ')
            if siz[1]=='KB':
                siz[0]=float(siz[0])/1025

            size=size+float(siz[0])
    print(f"{'%.1f' % size*1024} kb {end='',flush=True}")
    print('\r', end='', flush=True)

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import re
